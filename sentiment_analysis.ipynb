# %%
import pandas as pd

df = pd.read_excel('data/yt_comments_tokenized.xlsx')
df.head()
# Out:
#                                       vid_title       vid_uploader   c_author  \
# 0  '비혼모 출산' 사유리, 💎냉동난자💎까지 공개했던 속사정은? [비행소녀 43회]  MBN Entertainment      MI mi
# 1  '비혼모 출산' 사유리, 💎냉동난자💎까지 공개했던 속사정은? [비행소녀 43회]  MBN Entertainment        문은정
# 2  '비혼모 출산' 사유리, 💎냉동난자💎까지 공개했던 속사정은? [비행소녀 43회]  MBN Entertainment  Soonoknim
# 3  '비혼모 출산' 사유리, 💎냉동난자💎까지 공개했던 속사정은? [비행소녀 43회]  MBN Entertainment      릴렉스쪼꼬
# 4  '비혼모 출산' 사유리, 💎냉동난자💎까지 공개했던 속사정은? [비행소녀 43회]  MBN Entertainment         하트
#
#                                              content  like  \
# 0          응원합니다! \n부모같지 않은 쓰레기들보다는 백배 천배 더 훨 낫습니다!!   254
# 1  한번 사는 인생...사유리 하고 싶은대로...\n귀중한 아기 얻어서 사랑 많이 주면...   372
# 2  결혼해서 살다가 헤어지는 부부가 얼마나 많은데 그럼 아이들이 얼마나 상처받는데 그것...   202
# 3  나두 남자는 싫은데...애는 낳고싶다...하지만 능력도 능력이지만....애한테 미안...    97
# 4  난자도 소중히 보물이라 여기는 사유리\n혼자서도 충분히 아이사랑해주고 잘키우겠다 멋...   150
#
#                                            tokenized
# 0    ['응원', '부모', '쓰레기', '백배', '천배', '더', '훨', '낫다']
# 1  ['한번', '살다', '인생', '사유리', '싶다', '귀중하다', '아기', ...
# 2  ['결혼', '살다', '헤어지다', '부부', '얼마나', '많다', '아이', ...
# 3  ['나', '남자', '싫다', '애', '낳다', '능력', '능력', '애', ...
# 4  ['난자', '소중하다', '보물', '여기다', '사유리', '혼자', '서도',...

# %% [markdown]
# 1. 한국어 감성 사전 로드

# %%
f = open('data/SentiWord_Dict.txt', 'r', -1, 'utf-8')
lines = f.readlines()

score_dict = []

for line in lines:
    line_splited = line.split()
    score = int(line_splited[-1])
    word = ''
    for frac in line_splited[:-1]:
        word = word + ' ' + frac
    
    word = word[1:]
    score_dict.append([word, score])

# %% [markdown]
# 감성 지수 산출

# %%
import ast
df['positive'] = 0
df['negative'] = 0
df['neutral'] = 0

for i in range(len(df)):
    tokens = ast.literal_eval(df.loc[i, 'tokenized'])
    for token in tokens:
        for dict_word in score_dict:
            if dict_word[0] == token:
                if dict_word[1] > 0:
                    df.loc[i, 'positive'] += dict_word[1]
                elif dict_word[1] < 0:
                    df.loc[i, 'negative'] += dict_word[1]
                else:
                    df.loc[i, 'neutral'] += 1 #중립어는 개수 세기

# %% [markdown]
# 지수에 따른 라벨링

# %%
df['score'] = df['positive'] + df['negative']

for i in range(len(df)):
    if df.loc[i, 'score'] > 0:
        label = 'Positive'
    elif df.loc[i, 'score'] < 0:
        label = 'Negative'
    else:
        label = 'Neutral'    
    
    df.loc[i, 'label'] = label

# %%
df.to_excel('data/yt_comments_labled.xlsx', index = False)
